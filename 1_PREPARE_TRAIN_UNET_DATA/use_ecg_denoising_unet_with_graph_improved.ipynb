# %%
# Čia yra Python skriptas, skirtas EKG triukšmo aptikimui naudojant iš anksto apmokytą U-Net modelį
# su train_ecg_denoising_unetX.py. išskirčių (outliers) ir rspragų (rdropouts) neieškoma.
# Skriptas naudoja Keras bibliotekas, kad įkeltų modelį ir atliktų EKG signalų apdorojimą.

# Jei flag_plot_start_with_distortions_entire = True, išvedamas grafikas su anotuotais (dažoma geltonais)
# ir aptiktais triukšmais (dažoma raudonai)ir išsaugomas kaip paveikslėlis.
# R pikų nerodo.

# https://grok.com/chat/68e9c626-abf9-4fc3-9102-d82468902b6f

# Install missing dependencies for this notebook environment
# %pip install -q keras tensorflow

import pandas as pd
from pathlib import Path
import os, math, sys

# Fix: Import keras directly for model loading
import keras

# Prikabiname zive_util_ml, use_ecg_denoising_util, kurie yra lygiagrečiame aplanke TEST_UNET
# Assumes you're running the notebook in DUOMENYS_UPD
base_path = Path().resolve().parent / 'TEST_UNET'
sys.path.append(str(base_path))


from ecg_denoising_util import get_ecg_signal, get_ecg_noise_indices_annotated
from ecg_denoising_util import divide_signal_into_fragments, plot_signal_write_plot_R_P_1
from ecg_denoising_util import run_ecg_denoising_pipeline
from ecg_denoising_util import ecg_filter


        #   PARAMETRAI, APLANKAI IR KONFIGŪRACIJA 

# Duomenų aplankas su zive ir mit duomenimis
Duomenu_aplankas = Path.home() / 'DI/2025_ZIVEO/DUOMENYS_UPD'
Parametru_aplankas = Duomenu_aplankas/'PARAMETRAI'

# Aplankas su EKG įrašais (.npy) ir anotacijomis (.json)
db_folder = 'records_npy_all'  # zive
# db_folder = 'Igno'  # Igno Griskeviciaus

# Nuoroda į aplanką su EKG įrašais (.npy) ir anotacijomis (.json)
rec_dir = Path(Duomenu_aplankas, db_folder)


# start0
model_file_name = "resunet_ecg_1024_0_5_3_6.keras"

# resunet_ecg_1024_0_5_3_6.keras:
# 1024 - 'SEGMENT_LENGTH'
# 0_5 - 'OVERLAP'
# 3 - papildymas, leidžiantis susigaudyti su kokiais duomenimis buvo mokymas. 3 reiškia, kad naudojama mokymo imtis po 3-io
#  papildymo duomenimis (žr. 3-as etapas - duomenys mokymui). 
# 6 - pridėjau, kad būtų aišku, kad mokyta su train_ecg_denoising_unet6.py 


#  Configuration parameters (matched to training script)
CONFIG = {
    'FS': 200,              # Sampling rate
    'SEGMENT_LENGTH': 1024, # Segment length
    'OVERLAP': 0.5          # Overlap fraction
}

threshold = 0.15  # Residual threshold for noise detection (tune as needed)
threshold = 0.07  # Residual threshold for noise detection (tune as needed)
thresholds = [0.07, 0.08, 0.15]  # Residual thresholds for noise detection (tune as needed)
thresholds = [0.08]  # Residual threshold for noise detection (tune as needed)

segment_length = CONFIG['SEGMENT_LENGTH']
overlap = CONFIG['OVERLAP']
fs = CONFIG['FS']

# ECG įrašo filtravimui
fp = {  'type': 'lowpass',
            'method':'butterworth',
            'order':5,
            'sampling_rate':fs,
            'lowcut':0.5,
            'highcut':90 }

portion_length_in_secs = 10  # seconds

print(f"\nSTARTING NOISE DETECTION SCRIPT:")
print(f"\nConfiguration parameters: {CONFIG}")
print(f"threshold: {threshold}")
print(f"\nportion_length_in_secs: {portion_length_in_secs} secs")

print(f"\nDuomenų aplankas: {Duomenu_aplankas}")
print(f"Parametrų aplankas: {Parametru_aplankas}")
print("Filtravimo parametrai:", fp)

print(f"\nModel file name: {model_file_name}")

# Load the trained U-Net model in Keras format
parametru_aplankas = Duomenu_aplankas/'PARAMETRAI'    
model_path = os.path.join(parametru_aplankas, model_file_name) # Path to the trained model
print(f"\nTrying to load model from: {model_path}")
try:
    model = keras.models.load_model(model_path)
except Exception as e:
    raise ValueError(f"Failed to load model from {model_path}: {e}")

if model is None:
    raise ValueError(f"Model loading returned None. Check if the file exists and is a valid Keras model: {model_path}")

# Verify model input shape
if not hasattr(model, "input_shape") or model.input_shape is None:
    raise ValueError(f"Loaded model does not have a valid input_shape attribute. Model: {model}")

expected_input_shape = model.input_shape[1:]  # e.g., (1024, 1)
if expected_input_shape != (segment_length, 1):
    raise ValueError(f"Model expects input shape {expected_input_shape}, but script uses ({segment_length}, 1)")


        #   DUOMENYS

# Švarūs įrašai
fileNames = ['1102_1.npy', '1001_8.npy', '1005_4.npy', '1006_1.npy', '1001_6.npy']

# Rodomi įrašai
fileNames = ['1002_2.npy'] # Išskirčių:0, rspragų:0, kitų triukšmų:12 Triukšmų kiekis: 23.20%
fileNames = ['1008_22.npy'] # Gera kokybė Triukšmų kiekis: 89.60%
fileNames = ['1009_16.npy'] # 86.40% Triukšmų kiekis: 86.40%
fileNames = ['1031_18.npy'] # 80.19%% Didžioji įrašo dalis be kūno
fileNames = ['1001_1.npy'] # Išskirčių:0, rspragų:0, kitų triukšmų:12 Triukšmų kiekis: 22.40%

fileNames = ['1009_12.npy'] # Quality 0, Idealus, Triukšmų kiekis: 92.80%

# start1

# Žiūrimas įrašas
fileNames = ['1010_0.npy'] # 2222, geras, tik keletas vietų su triukšmais
fileNames = ['1001_8.npy'] # s
fileNames = ['1002_1.npy'] # s
fileNames = ['1026_0.npy'] # s
fileNames = ['1097_0.npy'] # s
fileNames = ['1015_63.npy'] # s


# ++++++++++++++++++++++++++++++ Testavimui
# Duomenų aplankas su zive ir mit duomenimis
# Duomenu_aplankas = Path.home() / 'DI/ZIVEO_2025/DUOMENYS_UPD'

# Aplankas su EKG įrašais (.npy) ir anotacijomis (.json)
# db_folder = 'noisy_ecg_for_test'  # zive
# db_folder = 'clean_ecg_for_test'  # zive
# rec_dir = Path(Duomenu_aplankas, db_folder)

# fileNames = ['1001_8_noised.npy']
# fileNames = ['1001_8.npy']
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++


for fileName in fileNames:
    
    # Load the ECG data from .npy file
    filePath = os.path.join(rec_dir, fileName)             
    print(f"\nFailas: {filePath}")
    print("Loading ECG data from ecg_record.npy")
    try:
        ecg_data_orig = get_ecg_signal(filePath)
        
         # Apply ecg filter
        ecg_data = ecg_filter(ecg_data_orig, fp)
        print(f"Lowpas filter applied, filtered signal length: {len(ecg_data)}")
    
        # Load corresponding JSON file
        json_path = os.path.splitext(filePath)[0] + '.json'
        noise_indices_annotated = get_ecg_noise_indices_annotated(json_path) 
        print(f"ECG data loaded, shape: {ecg_data.shape}")
    except Exception as e:
        raise RuntimeError("Failed to load ecg_record.npy") from e


    print(f"\nFILE:")  
    print(f"filePath: {filePath}")  
    print(f"Total signal length: {len(ecg_data)} samples ({len(ecg_data)/fs:.1f} secs)")
    # Surandami pažymėti triukšmai
    print(f"Noisy intervals annotated: {len(noise_indices_annotated)}")
    print(f"Noisy indices annotated (start, end): {noise_indices_annotated}")
    noise_indices_annotated_secs = [(x/fs, y/fs) for x, y in noise_indices_annotated]  # Convert to seconds
    print(f"Noisy indices annotated secs (start, end): {noise_indices_annotated_secs}")

    # Detektuojami triukšmai

    print("\nNOISE DETECTION:")
    print(f"Model file name: {model_file_name}")
    print(f"Configuration parameters: {CONFIG}")

    noisy_indices = []
    noisy_indices_secs = []
    for i,threshold in enumerate(thresholds):
        denoised_signal, noisy_indices = run_ecg_denoising_pipeline(ecg_data, model, CONFIG, threshold)
        print("\n========================================")
        print(f"threshold: {threshold}")
        print(f"Noisy intervals detected: {len(noisy_indices)}")
        print(f"Noisy indices: {noisy_indices}")
        noisy_indices_secs = [(x/fs, y/fs) for x, y in noisy_indices]  # Convert to seconds
        print(f"Noisy indices secs: {noisy_indices_secs}")

        # Compute noise percentage
        noise_range = sum(end - start + 1 for start, end in noisy_indices)
        percentage_covered = (noise_range / len(ecg_data)) * 100
        print(f"Noise percentage: {percentage_covered:.2f}%")
        
    # Ploting entire signal with all found distortions: outliers, rdropouts and oscillations
    flag_plot_start_with_distortions_entire = True
    portion_length = portion_length_in_secs * fs
        
    if flag_plot_start_with_distortions_entire:

        # bendras aplankas grafikams
        plot_save_dir = "PLOTTINGS_4"

        # Extract the numerical part from the fileName
        base_name = os.path.basename(fileName)

        flag_plot_save = False

        addition_to_name = 'orig'
        if flag_plot_save:
            plot_dir = os.path.join(plot_save_dir, base_name + '_plot_' + addition_to_name)
            if not os.path.exists(plot_dir):
                os.makedirs(plot_dir)
        else:
            plot_dir = None

        print(f"\nplot_dir: {plot_dir}")
        
        print(f"filtered_signal length: {len(ecg_data)} ({len(ecg_data)/fs:.1f} secs)")
        print(f"portion_length: {portion_length} ({portion_length_in_secs} secs)")
        print(f"portion_length_in_secs: {portion_length_in_secs} ({portion_length} samples)")
        print(f"fs: {fs} ({1/fs:.1f} secs)")


        # Sudalijame  ecg_signal_start į fragmentus
        show_frag_indices = divide_signal_into_fragments(ecg_data, portion_length)
        print()
        print(f"show_frag_indices: {show_frag_indices}")
        show_frag_indices_secs = [(x/fs, math.floor(y/fs)) for x, y in show_frag_indices] # indexes
        print(f"show_frag_indices_secs: {show_frag_indices_secs}")
            
        num_fragment = 1
        for (show_frag_start_secs, show_frag_end_secs) in show_frag_indices_secs:
            print(f"\nFRAGMENT NR. {num_fragment}")
            print(f"plot_signal_from_in_secs: {show_frag_start_secs}")
            print(f"plot_signal_to_in_secs: {show_frag_end_secs}")
            if (show_frag_end_secs - show_frag_start_secs) > 0.5:
                plot_signal_write_plot_R_P_1(fileName, ecg_data, fs, num_fragment,
                    show_frag_start_secs, show_frag_end_secs, portion_length_in_secs,
                        plot_dir, addition_to_name,recID=None,
                        gap1_indices_secs = noisy_indices_secs,  # red
                        gap2_indices_secs = [], # blue
                        gap3_indices_secs=noise_indices_annotated_secs, # yellow
                        # gap3_indices_secs=[],
                        mark_indices_secs=[],
                        # annot_df=annot_df,
                        annot_df=pd.DataFrame(),   # tuščias df,
                        rpeak_indices_secs=[], ppeak_indices_secs=[],
                        flag_secs=True)

            num_fragment += 1
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 2025-10-01 21:10:50.961933: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-01 21:10:52.199380: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-10-01 21:10:52.200163: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-10-01 21:10:52.390649: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-10-01 21:10:52.765260: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-01 21:10:52.770868: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-01 21:11:04.630850: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# STARTING NOISE DETECTION SCRIPT:
#
# Configuration parameters: {'FS': 200, 'SEGMENT_LENGTH': 1024, 'OVERLAP': 0.5}
# threshold: 0.07
#
# portion_length_in_secs: 10 secs
#
# Duomenų aplankas: /home/kesju/DI/2025_ZIVEO/DUOMENYS_UPD
# Parametrų aplankas: /home/kesju/DI/2025_ZIVEO/DUOMENYS_UPD/PARAMETRAI
# Filtravimo parametrai: {'type': 'lowpass', 'method': 'butterworth', 'order': 5, 'sampling_rate': 200, 'lowcut': 0.5, 'highcut': 90}
#
# Model file name: resunet_ecg_1024_0_5_3_6.keras
#
# Trying to load model from: /home/kesju/DI/2025_ZIVEO/DUOMENYS_UPD/PARAMETRAI/resunet_ecg_1024_0_5_3_6.keras
#
# Failas: /home/kesju/DI/2025_ZIVEO/DUOMENYS_UPD/records_npy_all/1015_63.npy
# Loading ECG data from ecg_record.npy
# Lowpas filter applied, filtered signal length: 127999
# ECG data loaded, shape: (127999,)
#
# FILE:
# filePath: /home/kesju/DI/2025_ZIVEO/DUOMENYS_UPD/records_npy_all/1015_63.npy
# Total signal length: 127999 samples (640.0 secs)
# Noisy intervals annotated: 0
# Noisy indices annotated (start, end): []
# Noisy indices annotated secs (start, end): []
#
# NOISE DETECTION:
# Model file name: resunet_ecg_1024_0_5_3_6.keras
# Configuration parameters: {'FS': 200, 'SEGMENT_LENGTH': 1024, 'OVERLAP': 0.5}
#
# ========================================
# threshold: 0.08
# Noisy intervals detected: 16
# Noisy indices: [(6656, 9727), (13824, 15871), (16384, 20991), (21504, 25087), (26112, 27135), (32768, 33791), (34304, 36351), (57344, 58879), (59392, 61439), (62464, 63487), (64000, 65023), (71168, 109055), (109568, 110591), (111616, 112639), (120832, 121855), (124928, 125951)]
# Noisy indices secs: [(33.28, 48.635), (69.12, 79.355), (81.92, 104.955), (107.52, 125.435), (130.56, 135.675), (163.84, 168.955), (171.52, 181.755), (286.72, 294.395), (296.96, 307.195), (312.32, 317.435), (320.0, 325.115), (355.84, 545.275), (547.84, 552.955), (558.08, 563.195), (604.16, 609.275), (624.64, 629.755)]
# Noise percentage: 50.80%
#
# plot_dir: None
# filtered_signal length: 127999 (640.0 secs)
# portion_length: 2000 (10 secs)
# portion_length_in_secs: 10 (2000 samples)
# fs: 200 (0.0 secs)
#
# show_frag_indices: [(0, 2000), (2000, 4000), (4000, 6000), (6000, 8000), (8000, 10000), (10000, 12000), (12000, 14000), (14000, 16000), (16000, 18000), (18000, 20000), (20000, 22000), (22000, 24000), (24000, 26000), (26000, 28000), (28000, 30000), (30000, 32000), (32000, 34000), (34000, 36000), (36000, 38000), (38000, 40000), (40000, 42000), (42000, 44000), (44000, 46000), (46000, 48000), (48000, 50000), (50000, 52000), (52000, 54000), (54000, 56000), (56000, 58000), (58000, 60000), (60000, 62000), (62000, 64000), (64000, 66000), (66000, 68000), (68000, 70000), (70000, 72000), (72000, 74000), (74000, 76000), (76000, 78000), (78000, 80000), (80000, 82000), (82000, 84000), (84000, 86000), (86000, 88000), (88000, 90000), (90000, 92000), (92000, 94000), (94000, 96000), (96000, 98000), (98000, 100000), (100000, 102000), (102000, 104000), (104000, 106000), (106000, 108000), (108000, 110000), (110000, 112000), (112000, 114000), (114000, 116000), (116000, 118000), (118000, 120000), (120000, 122000), (122000, 124000), (124000, 126000), (126000, 127999)]
# show_frag_indices_secs: [(0.0, 10), (10.0, 20), (20.0, 30), (30.0, 40), (40.0, 50), (50.0, 60), (60.0, 70), (70.0, 80), (80.0, 90), (90.0, 100), (100.0, 110), (110.0, 120), (120.0, 130), (130.0, 140), (140.0, 150), (150.0, 160), (160.0, 170), (170.0, 180), (180.0, 190), (190.0, 200), (200.0, 210), (210.0, 220), (220.0, 230), (230.0, 240), (240.0, 250), (250.0, 260), (260.0, 270), (270.0, 280), (280.0, 290), (290.0, 300), (300.0, 310), (310.0, 320), (320.0, 330), (330.0, 340), (340.0, 350), (350.0, 360), (360.0, 370), (370.0, 380), (380.0, 390), (390.0, 400), (400.0, 410), (410.0, 420), (420.0, 430), (430.0, 440), (440.0, 450), (450.0, 460), (460.0, 470), (470.0, 480), (480.0, 490), (490.0, 500), (500.0, 510), (510.0, 520), (520.0, 530), (530.0, 540), (540.0, 550), (550.0, 560), (560.0, 570), (570.0, 580), (580.0, 590), (590.0, 600), (600.0, 610), (610.0, 620), (620.0, 630), (630.0, 639)]
#
# FRAGMENT NR. 1
# plot_signal_from_in_secs: 0.0
# plot_signal_to_in_secs: 10
# FRAGMENT NR. 2
# plot_signal_from_in_secs: 10.0
# plot_signal_to_in_secs: 20
# FRAGMENT NR. 3
# plot_signal_from_in_secs: 20.0
# plot_signal_to_in_secs: 30
# FRAGMENT NR. 4
# plot_signal_from_in_secs: 30.0
# plot_signal_to_in_secs: 40
# FRAGMENT NR. 5
# plot_signal_from_in_secs: 40.0
# plot_signal_to_in_secs: 50
# FRAGMENT NR. 6
# plot_signal_from_in_secs: 50.0
# plot_signal_to_in_secs: 60
# FRAGMENT NR. 7
# plot_signal_from_in_secs: 60.0
# plot_signal_to_in_secs: 70
# FRAGMENT NR. 8
# plot_signal_from_in_secs: 70.0
# plot_signal_to_in_secs: 80
# FRAGMENT NR. 9
# plot_signal_from_in_secs: 80.0
# plot_signal_to_in_secs: 90
# FRAGMENT NR. 10
# plot_signal_from_in_secs: 90.0
# plot_signal_to_in_secs: 100
# FRAGMENT NR. 11
# plot_signal_from_in_secs: 100.0
# plot_signal_to_in_secs: 110
# FRAGMENT NR. 12
# plot_signal_from_in_secs: 110.0
# plot_signal_to_in_secs: 120
# FRAGMENT NR. 13
# plot_signal_from_in_secs: 120.0
# plot_signal_to_in_secs: 130
# FRAGMENT NR. 14
# plot_signal_from_in_secs: 130.0
# plot_signal_to_in_secs: 140
# FRAGMENT NR. 15
# plot_signal_from_in_secs: 140.0
# plot_signal_to_in_secs: 150
# FRAGMENT NR. 16
# plot_signal_from_in_secs: 150.0
# plot_signal_to_in_secs: 160
# FRAGMENT NR. 17
# plot_signal_from_in_secs: 160.0
# plot_signal_to_in_secs: 170
# FRAGMENT NR. 18
# plot_signal_from_in_secs: 170.0
# plot_signal_to_in_secs: 180
# FRAGMENT NR. 19
# plot_signal_from_in_secs: 180.0
# plot_signal_to_in_secs: 190
# FRAGMENT NR. 20
# plot_signal_from_in_secs: 190.0
# plot_signal_to_in_secs: 200
# FRAGMENT NR. 21
# plot_signal_from_in_secs: 200.0
# plot_signal_to_in_secs: 210
# FRAGMENT NR. 22
# plot_signal_from_in_secs: 210.0
# plot_signal_to_in_secs: 220
# FRAGMENT NR. 23
# plot_signal_from_in_secs: 220.0
# plot_signal_to_in_secs: 230
# FRAGMENT NR. 24
# plot_signal_from_in_secs: 230.0
# plot_signal_to_in_secs: 240
# FRAGMENT NR. 25
# plot_signal_from_in_secs: 240.0
# plot_signal_to_in_secs: 250
# FRAGMENT NR. 26
# plot_signal_from_in_secs: 250.0
# plot_signal_to_in_secs: 260
# FRAGMENT NR. 27
# plot_signal_from_in_secs: 260.0
# plot_signal_to_in_secs: 270
# FRAGMENT NR. 28
# plot_signal_from_in_secs: 270.0
# plot_signal_to_in_secs: 280
# FRAGMENT NR. 29
# plot_signal_from_in_secs: 280.0
# plot_signal_to_in_secs: 290
# FRAGMENT NR. 30
# plot_signal_from_in_secs: 290.0
# plot_signal_to_in_secs: 300
# FRAGMENT NR. 31
# plot_signal_from_in_secs: 300.0
# plot_signal_to_in_secs: 310
# FRAGMENT NR. 32
# plot_signal_from_in_secs: 310.0
# plot_signal_to_in_secs: 320
# FRAGMENT NR. 33
# plot_signal_from_in_secs: 320.0
# plot_signal_to_in_secs: 330
# FRAGMENT NR. 34
# plot_signal_from_in_secs: 330.0
# plot_signal_to_in_secs: 340
# FRAGMENT NR. 35
# plot_signal_from_in_secs: 340.0
# plot_signal_to_in_secs: 350
# FRAGMENT NR. 36
# plot_signal_from_in_secs: 350.0
# plot_signal_to_in_secs: 360
# FRAGMENT NR. 37
# plot_signal_from_in_secs: 360.0
# plot_signal_to_in_secs: 370
# FRAGMENT NR. 38
# plot_signal_from_in_secs: 370.0
# plot_signal_to_in_secs: 380
# FRAGMENT NR. 39
# plot_signal_from_in_secs: 380.0
# plot_signal_to_in_secs: 390
# FRAGMENT NR. 40
# plot_signal_from_in_secs: 390.0
# plot_signal_to_in_secs: 400
# FRAGMENT NR. 41
# plot_signal_from_in_secs: 400.0
# plot_signal_to_in_secs: 410
# FRAGMENT NR. 42
# plot_signal_from_in_secs: 410.0
# plot_signal_to_in_secs: 420
# FRAGMENT NR. 43
# plot_signal_from_in_secs: 420.0
# plot_signal_to_in_secs: 430
# FRAGMENT NR. 44
# plot_signal_from_in_secs: 430.0
# plot_signal_to_in_secs: 440
# FRAGMENT NR. 45
# plot_signal_from_in_secs: 440.0
# plot_signal_to_in_secs: 450
# FRAGMENT NR. 46
# plot_signal_from_in_secs: 450.0
# plot_signal_to_in_secs: 460
# FRAGMENT NR. 47
# plot_signal_from_in_secs: 460.0
# plot_signal_to_in_secs: 470
# FRAGMENT NR. 48
# plot_signal_from_in_secs: 470.0
# plot_signal_to_in_secs: 480
# FRAGMENT NR. 49
# plot_signal_from_in_secs: 480.0
# plot_signal_to_in_secs: 490
# FRAGMENT NR. 50
# plot_signal_from_in_secs: 490.0
# plot_signal_to_in_secs: 500
# FRAGMENT NR. 51
# plot_signal_from_in_secs: 500.0
# plot_signal_to_in_secs: 510
# FRAGMENT NR. 52
# plot_signal_from_in_secs: 510.0
# plot_signal_to_in_secs: 520
# FRAGMENT NR. 53
# plot_signal_from_in_secs: 520.0
# plot_signal_to_in_secs: 530
# FRAGMENT NR. 54
# plot_signal_from_in_secs: 530.0
# plot_signal_to_in_secs: 540
# FRAGMENT NR. 55
# plot_signal_from_in_secs: 540.0
# plot_signal_to_in_secs: 550
# FRAGMENT NR. 56
# plot_signal_from_in_secs: 550.0
# plot_signal_to_in_secs: 560
# FRAGMENT NR. 57
# plot_signal_from_in_secs: 560.0
# plot_signal_to_in_secs: 570
# FRAGMENT NR. 58
# plot_signal_from_in_secs: 570.0
# plot_signal_to_in_secs: 580
# FRAGMENT NR. 59
# plot_signal_from_in_secs: 580.0
# plot_signal_to_in_secs: 590
# FRAGMENT NR. 60
# plot_signal_from_in_secs: 590.0
# plot_signal_to_in_secs: 600
# FRAGMENT NR. 61
# plot_signal_from_in_secs: 600.0
# plot_signal_to_in_secs: 610
# FRAGMENT NR. 62
# plot_signal_from_in_secs: 610.0
# plot_signal_to_in_secs: 620
# FRAGMENT NR. 63
# plot_signal_from_in_secs: 620.0
# plot_signal_to_in_secs: 630
# FRAGMENT NR. 64
# plot_signal_from_in_secs: 630.0
# plot_signal_to_in_secs: 639
