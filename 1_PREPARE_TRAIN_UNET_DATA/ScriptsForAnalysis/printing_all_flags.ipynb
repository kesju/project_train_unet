# %%
# Comparing of list of Annotated View records with records with metadata from Excel

from __future__ import annotations

import json
from pathlib import Path
from typing import Dict, List, Optional, Tuple, TypedDict, Any, Set
from collections import Counter
import pandas as pd
import sys

# funkcija skaito Excel su įrašų sąrašu ir meta duomenimis 
def read_filenames_from_excel(xlsx_path: Path) -> tuple[list[str], pd.DataFrame]:
    """Skaito Excel, grąžina sąrašą `.npy` failų ir visą DF (meta duomenims paimti)."""
    print("\nSkaitomas Excel: %s", xlsx_path)
    df = pd.read_excel(xlsx_path, dtype=str)  # saugu tolimesnėms konversijoms
    if "filename" not in df.columns or "tag" not in df.columns:
        raise ValueError("Excel must contain columns: 'filename' and 'tag'")

    # filtered = df[df["tag"] != "9999"]
    filtered = df
    names = []
    for s in filtered["filename"].dropna():
        name = str(s).strip()
        if not name.endswith(".npy"):
            name += ".npy"
        names.append(name)

    print("Įrašų sąraše:", len(names))
    return names, df

def _read_json_data(json_path: Path) -> Optional[Dict[str, Any]]:
    """
    Reads JSON file and returns parsed dict.
    Returns None if file does not exist, JSON is invalid, or top-level is not a dict.
    """
    if not json_path.exists():
        return None

    try:
        with open(json_path, "r", encoding="utf-8", errors="ignore") as f:
            data = json.load(f)
    except (json.JSONDecodeError, OSError):
        return None

    if not isinstance(data, dict):
        return None

    return data

from pathlib import Path
from typing import Any, Dict, Optional, Set, List
import json
import pandas as pd

# assumes these already exist in your code:
# _read_json_data(json_path: Path) -> Optional[Dict[str, Any]]
# _extract_raw_flags_set(data: Dict[str, Any]) -> Optional[Set[str]]

DEFAULT_KNOWN_FLAGS = [
    "PSEUDO_ANNOTATED",
    "FOR_EXTERNAL_ANNOTATING",
    "EXTERNALLY_ANNOTATED",
    "FULLY_ANNOTATED_PROFESSIONALLY",
]

def flags_str_for_filename(
    fname: str,
    rec_dir: Path,
    known_flags: Optional[List[str]] = None,
) -> str:
    """
    Reads <rec_dir>/<fname>.json, extracts flags, and returns a comma-separated string
    of known_flags that are present. Returns "" if missing/invalid.
    """
    known_flags = known_flags or DEFAULT_KNOWN_FLAGS

    json_path = (rec_dir / fname).with_suffix(".json")

    data = _read_json_data(json_path)
    if data is None:
        return ""  # or "MISSING/INVALID"

    raw_flags_set = _extract_raw_flags_set(data)
    if raw_flags_set is None:
        return ""  # invalid flags structure

    return ",".join(sorted(raw_flags_set))


def _extract_raw_flags_set(data: Dict[str, Any]) -> Optional[Set[str]]:
    """
    Extracts flags from JSON data and returns them as a set of strings.
    Returns None if 'flags' exists but is not a list (invalid structure).
    """
    raw_flags = data.get("flags")

    if raw_flags is None:
        raw_flags_list: List[str] = []
    elif isinstance(raw_flags, list):
        raw_flags_list = [str(x) for x in raw_flags]
    else:
        return None  # invalid structure

    return set(raw_flags_list)


# csv_path = Path("AnnotatedViewList_2026_01_22.csv")  # or full path
# df = pd.read_csv(csv_path)

# If you want a list of timestamps as strings (already like xxxxxxx.xxx)
# csv_names = df["timestamp"].astype(str).tolist()

# Filenames with a suffix you choose
# filenames_npy  = [f"{t}.npy" for t in timestamps]
# filenames_json = [f"{t}.json" for t in timestamps]
# filenames_dat  = [f"{t}.dat" for t in timestamps]

# print(csv_names)

# === Išoriniai moduliai (lygiagretus aplankas) =================================
PARALLEL_PATH = Path().resolve().parent / "../SUPL_FUNCTIONS"
sys.path.append(str(PARALLEL_PATH))

from project_util import find_project_root_by_name


PROJECT_DIR = Path(__file__).resolve().parent if "__file__" in globals() else Path.cwd()
PROJECT_ROOT = find_project_root_by_name(target="PROJECT_TRAIN_UNET", start=PROJECT_DIR)
print("\nPROJECT ROOT DIR:", PROJECT_ROOT)
print("PROJECT DIR:", PROJECT_DIR)

LIST_DIR = PROJECT_ROOT / '1_PREPARE_TRAIN_UNET_DATA'/ 'ecg_zive_npy_for_preparing'
REC_DIR = PROJECT_ROOT / "DATA_ORIG/ecg_zive_npy"
# EXCEL_NAME = "visi_zive_irasai_atrankai_test.xlsx"
EXCEL_NAME = "visi_zive_irasai_atrankai.xlsx"

print("\nLIST_DIR:", LIST_DIR)
print("REC_DIR:", REC_DIR)
print("EXCEL_NAME:", EXCEL_NAME)

file_names, df_meta = read_filenames_from_excel(LIST_DIR / EXCEL_NAME)
# print(file_names)

# filter matches
# matches = df_meta[df_meta["basename"].isin(csv_names)].copy()

# print(f"CSV files: {len(csv_names)}")
print(f"Excel rows: {len(df_meta)}")
# print(f"Matches: {len(matches)}")

def flags_from_filename(fn: str) -> str:
    json_path = (REC_DIR / fn).with_suffix(".json")

    data = _read_json_data(json_path)
    if data is None:
        return ""  # or "MISSING/INVALID"

    raw_flags_set = _extract_raw_flags_set(data)
    print(json_path.stem, raw_flags_set)
    if raw_flags_set is None:
        return ""  # invalid structure

    return ",".join(sorted(raw_flags_set))  # stable order for printing

# for filename in file_names:
#     flags = flags_from_filename(filename)
#     print(f"{filename}: {flags}")

# from pathlib import Path
import pandas as pd

rows = []
for i, filename in enumerate(file_names, start=1):
    flags = flags_from_filename(filename)
    rows.append({
        "nr": i,
        "filename": filename,
        "flags": flags,  # if this is a list, see note below
    })

df = pd.DataFrame(rows, columns=["nr", "filename", "flags"])

# If flags is a list/set/dict, convert to a readable string
df["flags"] = df["flags"].apply(
    lambda x: "|".join(map(str, x)) if isinstance(x, (list, tuple, set))
    else (str(x) if x is not None else "")
)

out_xlsx = Path("file_flags.xlsx")
df.to_excel(out_xlsx, index=False)

print(f"Wrote: {out_xlsx.resolve()}")

# matches = matches.copy()
# matches["flags"] = matches["filename"].astype(str).apply(flags_from_filename)


# cols_to_show = [c for c in ["filename", "recordingId", "userId", "tag", "basename", "flags"] if c in matches.columns]
# print("\n=== MATCHES (same basename) ===")
# print(matches[cols_to_show].to_string(index=False))

# Surandami unikalūs userId ir jų pasikartojimai
# user_counts_df = (
#     matches["userId"]
#     .dropna()
#     .astype(str)
#     .value_counts()
#     .rename_axis("userId")
#     .reset_index(name="count")
# )
# print(user_counts_df.head())
# print("\nSurandami unikalūs userId ir jų pasikartojimai:")
# print(user_counts_df.to_string(index=False))

# 6144c682bd0cc5acb727536 inmed20@zive.io


# print matching cases (choose the columns you want to see)
# cols_to_show = [c for c in ["filename", "recordingId", "tag", "basename"] if c in matches.columns]
# print("\n=== MATCHES (same basename) ===")
# print(matches[cols_to_show].to_string(index=False))

# If you also want to print CSV entries not found in Excel and Excel entries not in CSV, tell me and I’ll add the two “missing” lists (it’s ~10 extra lines).
# Out:
# ['1626330.744', '1626924.927', '1626934.963', '1626941.468', '1630673.825', '1630693.635', '1630757.303', '1630757.924', '1630758.549', '1630759.17', '1630761.032', '1630762.273', '1630762.894', '1630763.516', '1630764.137', '1630768.486', '1630770.348', '1630771.589', '1630777.178', '1630844.567', '1630845.187', '1630846.425', '1630922.972', '1630923.598', '1630924.224', '1630924.849', '1630925.473', '1630926.102', '1630926.726', '1630927.98', '1630928.606', '1630930.48', '1630931.105', '1630931.73', '1630932.359', '1630932.984', '1630936.742', '1630940.501', '1630941.126', '1630941.751', '1630943.629', '1630944.253', '1630949.261', '1630951.771', '1630957.402', '1630958.03', '1630958.655', '1630959.28', '1630959.909', '1630960.534', '1630961.159', '1630961.788', '1630962.413', '1630963.038', '1630964.293', '1630964.918', '1630969.301', '1630969.93', '1630981.205', '1630981.83', '1630986.207', '1631003.727', '1631009.364', '1631009.724', '1631010.352', '1631011.609', '1631012.235', '1631012.861', '1631015.999', '1631028.536', '1631055.852', '1631056.479', '1631057.107', '1631057.738', '1631070.474', '1631079.236', '1631082.981', '1631086.728', '1631087.981', '1631089.859', '1631090.342', '1631091.114', '1631093.618', '1631094.243', '1631094.872', '1631139.883', '1631702.918', '1631727.631', '1631734.441', '1632394.636', '1632396.522', '1632398.405', '1632469.959', '1632470.586', '1632471.213', '1632923.661', '1717637.692', '1717692.548', '1731438.42', '1742295.469', '1744875.093', '1744875.328', '1744875.951', '1744876.572', '1744877.194']
#
# PROJECT ROOT DIR: /home/kesju/DI/2025_ZIVEO/PROJECT_TRAIN_UNET
# PROJECT DIR: /home/kesju/DI/2025_ZIVEO/PROJECT_TRAIN_UNET/0_COLLECT_ZIVE_DATA/DUOM_2023
#
# LIST_DIR: /home/kesju/DI/2025_ZIVEO/PROJECT_TRAIN_UNET/1_PREPARE_TRAIN_UNET_DATA/ecg_zive_npy_for_preparing
# REC_DIR: /home/kesju/DI/2025_ZIVEO/PROJECT_TRAIN_UNET/DATA_ORIG/ecg_zive_npy
# EXCEL_NAME: visi_zive_irasai_atrankai.xlsx
#
# Skaitomas Excel: %s /home/kesju/DI/2025_ZIVEO/PROJECT_TRAIN_UNET/1_PREPARE_TRAIN_UNET_DATA/ecg_zive_npy_for_preparing/visi_zive_irasai_atrankai.xlsx
# Įrašų sąraše: 1092
# Excel rows: 1092
# 1000_1 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1000_2 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1001_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1001_1 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1001_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1001_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1001_4 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1001_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1001_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1001_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1001_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1002_0 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1002_1 {'FULLY_ANNOTATED_PROFESSIONALLY', 'AI_DATASET'}
# 1002_2 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED', 'AI_DATASET'}
# 1002_3 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1002_4 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED', 'PSEUDO_ANNOTATED'}
# 1002_5 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1002_6 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1003_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1003_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1004_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1004_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1004_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1005_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1005_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1005_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1005_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1005_12 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1005_13 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1005_14 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1005_15 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1005_16 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1005_17 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1005_2 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1005_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1005_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1005_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1005_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1005_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1005_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1005_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1006_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1006_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1006_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1006_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1007_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1007_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1008_0 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1008_1 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1008_10 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1008_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1008_12 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1008_13 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1008_14 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1008_15 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1008_16 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1008_17 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1008_18 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1008_19 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1008_2 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1008_20 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1008_21 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1008_22 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1008_23 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1008_24 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1008_3 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED', 'AI_DATASET'}
# 1008_4 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1008_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1008_6 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1008_7 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1008_8 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1008_9 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1009_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1009_1 {'FULLY_ANNOTATED_PROFESSIONALLY', 'AI_DATASET'}
# 1009_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1009_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1009_12 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1009_13 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1009_14 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1009_15 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1009_16 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1009_17 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1009_18 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1009_19 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1009_2 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1009_20 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1009_21 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1009_22 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1009_23 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1009_24 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1009_25 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1009_26 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1009_27 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1009_28 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1009_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1009_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1009_5 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1009_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1009_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1009_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1009_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1010_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1010_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1011_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1011_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1011_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1012_0 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1012_1 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1012_2 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1013_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_12 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_13 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_14 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_15 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_16 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_17 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_18 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_19 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_20 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_21 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_22 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_23 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_24 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_25 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_26 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_27 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_28 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_29 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_30 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_31 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_32 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_33 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_34 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_35 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_36 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_37 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_38 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_39 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_40 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1013_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1014_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_12 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_13 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_14 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_15 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_16 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_17 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_18 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_19 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_20 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_21 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_22 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_23 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_24 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_25 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_26 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_27 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_28 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_29 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_30 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_31 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_32 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_33 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_34 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_35 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_36 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_37 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_38 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_39 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_40 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_41 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_42 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_43 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_44 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_45 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_46 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_47 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_48 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_49 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_50 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_51 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_52 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_53 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_54 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_55 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_56 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_57 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_58 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_59 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_60 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_61 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_62 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_63 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_64 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1015_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1016_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1016_1 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1017_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1018_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1018_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1018_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1018_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1018_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1018_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1018_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1018_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1018_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_100 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_101 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_102 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_103 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_104 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_105 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_106 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_107 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_108 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_109 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_110 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_111 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_112 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_113 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_114 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_115 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_116 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_117 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_118 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_119 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_12 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_120 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_121 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_122 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_123 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_124 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_125 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_126 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_127 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_128 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_129 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_13 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_130 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_131 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_132 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_133 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_134 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_135 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_14 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_15 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_16 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_17 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_18 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_19 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_2 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_20 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_21 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_22 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_23 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_24 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_25 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_26 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1019_27 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_28 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_29 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_30 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_31 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_32 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_33 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_34 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_35 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_36 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_37 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_38 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_39 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_4 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_40 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_41 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1019_42 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_43 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_44 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_45 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_46 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_47 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_48 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_49 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_50 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_51 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_52 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_53 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_54 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1019_55 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_56 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_57 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_58 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_59 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_60 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_61 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_62 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_63 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_64 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_65 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_66 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_67 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_68 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_69 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_70 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_71 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_72 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_73 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_74 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_75 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_76 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_77 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_78 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_79 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_80 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_81 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_82 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_83 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_84 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_85 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_86 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_87 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_88 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_89 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_90 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_91 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_92 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_93 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_94 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_95 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_96 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_97 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_98 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1019_99 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1020_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1020_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1020_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1021_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1022_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1023_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1024_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1024_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1025_0 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1025_1 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1025_2 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1025_3 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1025_4 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1026_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1026_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1026_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1026_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1026_12 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1026_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1026_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1026_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1026_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1026_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1026_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1026_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1026_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1027_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1027_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1027_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1027_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1027_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1028_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1028_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1028_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1028_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1029_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1029_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_12 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_13 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_14 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_15 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_16 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_17 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_18 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_19 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_20 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_21 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_22 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_23 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_24 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_25 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_26 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_27 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_28 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_29 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_30 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_31 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_32 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_33 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1030_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_12 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_13 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_14 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_15 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_16 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_17 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_18 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_19 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_20 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_21 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_22 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_23 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_24 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_25 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_26 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_27 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_28 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_29 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_30 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_31 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_32 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_33 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_34 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_35 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_36 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_37 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_38 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_39 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_40 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_41 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_42 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_43 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_44 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_45 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_46 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_47 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_48 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_49 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_50 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_51 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_52 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_53 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_54 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_55 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_56 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1031_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1032_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1033_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1033_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1033_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1033_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1033_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1033_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1033_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1034_0 {'BAD_QUALITY', 'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_100 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_101 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_102 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_103 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_104 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_105 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_106 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_107 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_108 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_109 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_110 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_111 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_112 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_113 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_114 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_115 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_116 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_117 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_118 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_119 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_12 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_120 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_121 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_122 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_123 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_124 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_125 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_126 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_127 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_128 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_129 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_13 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_130 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_131 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_132 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_133 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_134 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_135 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_136 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_14 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_15 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_16 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_17 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_18 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_19 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_20 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_21 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_22 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_23 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_24 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_25 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_26 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_27 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_28 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_29 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_30 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_31 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_32 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_33 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_34 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_35 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_36 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_37 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_38 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_39 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_40 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_41 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_42 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_43 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_44 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_45 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_46 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_47 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_48 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_49 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_50 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_51 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_52 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_53 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_54 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_55 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_56 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_57 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_58 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_59 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_60 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_61 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_62 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_63 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_64 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_65 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_66 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_67 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_68 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_69 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_70 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_71 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_72 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_73 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_74 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_75 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_76 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_77 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_78 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_79 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_80 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_81 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_82 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_83 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_84 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_85 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_86 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_87 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_88 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_89 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_90 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_91 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_92 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_93 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_94 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_95 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_96 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_97 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_98 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1035_99 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1036_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1036_1 {'BAD_QUALITY', 'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1037_0 {'BAD_QUALITY', 'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1037_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1037_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1037_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1037_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1037_5 {'BAD_QUALITY', 'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1037_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1037_7 {'BAD_QUALITY', 'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1038_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1039_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1040_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1040_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1040_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1040_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1040_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1041_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1041_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_12 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_13 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_14 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_15 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_16 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_17 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_18 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_19 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_20 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_21 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_22 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_23 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_24 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_25 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_26 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_27 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1042_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1043_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1043_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1044_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1045_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1046_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1047_0 {'BAD_QUALITY', 'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1048_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1048_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1049_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1050_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1050_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1050_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1050_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1050_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1050_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1050_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1051_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1051_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1052_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1052_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1052_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1052_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1052_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1052_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1052_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1052_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1052_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1052_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1052_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1052_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_12 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_13 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_14 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_15 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_16 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_17 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_18 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_19 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_20 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_21 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_22 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_23 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_24 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1053_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1054_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1054_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1054_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1054_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1054_12 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1054_13 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1054_14 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1054_15 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1054_16 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1054_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1054_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1054_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1054_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1054_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1054_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1054_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1054_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1055_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1055_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1055_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1055_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1055_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1055_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1056_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1056_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1056_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1056_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1056_12 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1056_13 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1056_14 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1056_15 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1056_16 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1056_17 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1056_18 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1056_19 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1056_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1056_20 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1056_21 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1056_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1056_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1056_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1056_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1056_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1056_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1056_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1057_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1057_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1057_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1057_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1057_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1057_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1057_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1058_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1058_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1058_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1059_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1059_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1060_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1060_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1060_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1061_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1062_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1062_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1063_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1063_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1064_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1064_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1064_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1064_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1064_12 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1064_13 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1064_14 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1064_15 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1064_16 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1064_17 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1064_18 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1064_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1064_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1064_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1064_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1064_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1064_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1064_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1064_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1065_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1065_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1065_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1065_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1065_12 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1065_13 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1065_14 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1065_15 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1065_16 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1065_17 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1065_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1065_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1065_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1065_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1065_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1065_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1065_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1065_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1066_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1066_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1066_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1066_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1066_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1066_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1067_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1067_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1067_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1067_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1067_12 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1067_13 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1067_14 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1067_15 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1067_16 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1067_17 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1067_18 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1067_19 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1067_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1067_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1067_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1067_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1067_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1067_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1067_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1067_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1068_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1068_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1068_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1069_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1069_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1069_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1069_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1069_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1069_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1070_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1070_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1070_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1070_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1070_12 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1070_13 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1070_14 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1070_15 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1070_16 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1070_17 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1070_18 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1070_19 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1070_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1070_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1070_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1070_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1070_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1070_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1070_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1070_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_12 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_13 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_14 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_15 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_16 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_17 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_18 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_19 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_20 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_21 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_22 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_23 {'BAD_QUALITY', 'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_24 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1071_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1072_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1072_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1072_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1072_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1072_12 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1072_13 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1072_14 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1072_15 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1072_16 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1072_17 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1072_18 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1072_19 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1072_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1072_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1072_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1072_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1072_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1072_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1072_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1072_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1073_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1073_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1074_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1074_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1074_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1074_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1074_12 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1074_13 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1074_14 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1074_15 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1074_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1074_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1074_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1074_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1074_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1074_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1074_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1074_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1075_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1075_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1075_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1075_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1075_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1075_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1075_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1075_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1076_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1077_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1077_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1077_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1077_11 {'BAD_QUALITY', 'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1077_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1077_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1077_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1077_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1077_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1077_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1077_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1077_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1078_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1079_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1079_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1079_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1079_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1079_12 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1079_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1079_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1079_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1079_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1079_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1079_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1079_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1079_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1080_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1080_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1080_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1080_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1080_12 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1080_13 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1080_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1080_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1080_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1080_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1080_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1080_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1080_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1080_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1081_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1081_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1081_10 {'BAD_QUALITY', 'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1081_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1081_12 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1081_13 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1081_14 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1081_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1081_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1081_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1081_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1081_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1081_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1081_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1081_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1082_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1083_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1083_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1083_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1083_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1084_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1084_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1084_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1084_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1084_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1084_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1084_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1084_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1084_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1084_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1084_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1084_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1085_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1086_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1086_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1086_10 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1086_11 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1086_12 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1086_13 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1086_14 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1086_15 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1086_16 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1086_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1086_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1086_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1086_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1086_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1086_7 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1086_8 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1086_9 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1087_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1087_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1088_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1089_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1089_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1089_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1089_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1089_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1090_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1091_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1092_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1092_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1093_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1093_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1094_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1095_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1096_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1097_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1097_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1097_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1097_3 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1097_4 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1097_5 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1097_6 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1098_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1099_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1100_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1100_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1101_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1101_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1102_0 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1102_1 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1103_0 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# Wrote: /home/kesju/DI/2025_ZIVEO/PROJECT_TRAIN_UNET/0_COLLECT_ZIVE_DATA/DUOM_2023/file_flags.xlsx
