# %%
# Comparing of list of Annotated View records with records with metadata from Excel

from __future__ import annotations

import json
from pathlib import Path
from typing import Dict, List, Optional, Tuple, TypedDict, Any, Set
from collections import Counter
import pandas as pd
import sys

# funkcija skaito Excel su įrašų sąrašu ir meta duomenimis 
def read_filenames_from_excel(xlsx_path: Path) -> tuple[list[str], pd.DataFrame]:
    """Skaito Excel, grąžina sąrašą `.npy` failų ir visą DF (meta duomenims paimti)."""
    print("\nSkaitomas Excel: %s", xlsx_path)
    df = pd.read_excel(xlsx_path, dtype=str)  # saugu tolimesnėms konversijoms
    if "filename" not in df.columns or "tag" not in df.columns:
        raise ValueError("Excel must contain columns: 'filename' and 'tag'")

    filtered = df[df["tag"] != "9999"]
    names = []
    for s in filtered["filename"].dropna():
        name = str(s).strip()
        if not name.endswith(".npy"):
            name += ".npy"
        names.append(name)

    print("Įrašų sąraše:", len(names))
    return names, df

def _read_json_data(json_path: Path) -> Optional[Dict[str, Any]]:
    """
    Reads JSON file and returns parsed dict.
    Returns None if file does not exist, JSON is invalid, or top-level is not a dict.
    """
    if not json_path.exists():
        return None

    try:
        with open(json_path, "r", encoding="utf-8", errors="ignore") as f:
            data = json.load(f)
    except (json.JSONDecodeError, OSError):
        return None

    if not isinstance(data, dict):
        return None

    return data

from pathlib import Path
from typing import Any, Dict, Optional, Set, List
import json
import pandas as pd

# assumes these already exist in your code:
# _read_json_data(json_path: Path) -> Optional[Dict[str, Any]]
# _extract_raw_flags_set(data: Dict[str, Any]) -> Optional[Set[str]]

DEFAULT_KNOWN_FLAGS = [
    "PSEUDO_ANNOTATED",
    "FOR_EXTERNAL_ANNOTATING",
    "EXTERNALLY_ANNOTATED",
    "FULLY_ANNOTATED_PROFESSIONALLY",
]

def flags_str_for_filename(
    fname: str,
    rec_dir: Path,
    known_flags: Optional[List[str]] = None,
) -> str:
    """
    Reads <rec_dir>/<fname>.json, extracts flags, and returns a comma-separated string
    of known_flags that are present. Returns "" if missing/invalid.
    """
    known_flags = known_flags or DEFAULT_KNOWN_FLAGS

    json_path = (rec_dir / fname).with_suffix(".json")

    data = _read_json_data(json_path)
    if data is None:
        return ""  # or "MISSING/INVALID"

    raw_flags_set = _extract_raw_flags_set(data)
    if raw_flags_set is None:
        return ""  # invalid flags structure

    return ",".join(sorted(raw_flags_set))


def _extract_raw_flags_set(data: Dict[str, Any]) -> Optional[Set[str]]:
    """
    Extracts flags from JSON data and returns them as a set of strings.
    Returns None if 'flags' exists but is not a list (invalid structure).
    """
    raw_flags = data.get("flags")

    if raw_flags is None:
        raw_flags_list: List[str] = []
    elif isinstance(raw_flags, list):
        raw_flags_list = [str(x) for x in raw_flags]
    else:
        return None  # invalid structure

    return set(raw_flags_list)


csv_path = Path("AnnotatedViewList_2026_01_22.csv")  # or full path
df = pd.read_csv(csv_path)

# If you want a list of timestamps as strings (already like xxxxxxx.xxx)
csv_names = df["timestamp"].astype(str).tolist()

# Filenames with a suffix you choose
# filenames_npy  = [f"{t}.npy" for t in timestamps]
# filenames_json = [f"{t}.json" for t in timestamps]
# filenames_dat  = [f"{t}.dat" for t in timestamps]

print(csv_names)

# === Išoriniai moduliai (lygiagretus aplankas) =================================
PARALLEL_PATH = Path().resolve().parent / "SUPL_FUNCTIONS"
sys.path.append(str(PARALLEL_PATH))

from project_util import find_project_root_by_name


PROJECT_DIR = Path(__file__).resolve().parent if "__file__" in globals() else Path.cwd()
PROJECT_ROOT = find_project_root_by_name(target="PROJECT_TRAIN_UNET", start=PROJECT_DIR)
print("\nPROJECT ROOT DIR:", PROJECT_ROOT)
print("PROJECT DIR:", PROJECT_DIR)

LIST_DIR = PROJECT_ROOT / '1_PREPARE_TRAIN_UNET_DATA'/ 'ecg_zive_npy_for_preparing'
REC_DIR = PROJECT_ROOT / "DATA_ORIG/ecg_zive_npy"
# EXCEL_NAME = "visi_zive_irasai_atrankai_test.xlsx"
EXCEL_NAME = "visi_zive_irasai_atrankai.xlsx"

print("\nLIST_DIR:", LIST_DIR)
print("REC_DIR:", REC_DIR)
print("EXCEL_NAME:", EXCEL_NAME)

file_names, df_meta = read_filenames_from_excel(LIST_DIR / EXCEL_NAME)
# print(file_names)

# filter matches
matches = df_meta[df_meta["basename"].isin(csv_names)].copy()

print(f"CSV files: {len(csv_names)}")
print(f"Excel rows: {len(df_meta)}")
print(f"Matches: {len(matches)}")

def flags_from_filename(fn: str) -> str:
    json_path = (REC_DIR / fn).with_suffix(".json")

    data = _read_json_data(json_path)
    if data is None:
        return ""  # or "MISSING/INVALID"

    raw_flags_set = _extract_raw_flags_set(data)
    print(json_path.stem, raw_flags_set)
    if raw_flags_set is None:
        return ""  # invalid structure

    return ",".join(sorted(raw_flags_set))  # stable order for printing

matches = matches.copy()
matches["flags"] = matches["filename"].astype(str).apply(flags_from_filename)


cols_to_show = [c for c in ["filename", "recordingId", "userId", "tag", "basename", "flags"] if c in matches.columns]
print("\n=== MATCHES (same basename) ===")
print(matches[cols_to_show].to_string(index=False))

# Surandami unikalūs userId ir jų pasikartojimai
user_counts_df = (
    matches["userId"]
    .dropna()
    .astype(str)
    .value_counts()
    .rename_axis("userId")
    .reset_index(name="count")
)
print(user_counts_df.head())
print("\nSurandami unikalūs userId ir jų pasikartojimai:")
print(user_counts_df.to_string(index=False))

# 6144c682bd0cc5acb727536 inmed20@zive.io


# print matching cases (choose the columns you want to see)
# cols_to_show = [c for c in ["filename", "recordingId", "tag", "basename"] if c in matches.columns]
# print("\n=== MATCHES (same basename) ===")
# print(matches[cols_to_show].to_string(index=False))

# If you also want to print CSV entries not found in Excel and Excel entries not in CSV, tell me and I’ll add the two “missing” lists (it’s ~10 extra lines).
# Out:
# ['1626330.744', '1626924.927', '1626934.963', '1626941.468', '1630673.825', '1630693.635', '1630757.303', '1630757.924', '1630758.549', '1630759.17', '1630761.032', '1630762.273', '1630762.894', '1630763.516', '1630764.137', '1630768.486', '1630770.348', '1630771.589', '1630777.178', '1630844.567', '1630845.187', '1630846.425', '1630922.972', '1630923.598', '1630924.224', '1630924.849', '1630925.473', '1630926.102', '1630926.726', '1630927.98', '1630928.606', '1630930.48', '1630931.105', '1630931.73', '1630932.359', '1630932.984', '1630936.742', '1630940.501', '1630941.126', '1630941.751', '1630943.629', '1630944.253', '1630949.261', '1630951.771', '1630957.402', '1630958.03', '1630958.655', '1630959.28', '1630959.909', '1630960.534', '1630961.159', '1630961.788', '1630962.413', '1630963.038', '1630964.293', '1630964.918', '1630969.301', '1630969.93', '1630981.205', '1630981.83', '1630986.207', '1631003.727', '1631009.364', '1631009.724', '1631010.352', '1631011.609', '1631012.235', '1631012.861', '1631015.999', '1631028.536', '1631055.852', '1631056.479', '1631057.107', '1631057.738', '1631070.474', '1631079.236', '1631082.981', '1631086.728', '1631087.981', '1631089.859', '1631090.342', '1631091.114', '1631093.618', '1631094.243', '1631094.872', '1631139.883', '1631702.918', '1631727.631', '1631734.441', '1632394.636', '1632396.522', '1632398.405', '1632469.959', '1632470.586', '1632471.213', '1632923.661', '1717637.692', '1717692.548', '1731438.42', '1742295.469', '1744875.093', '1744875.328', '1744875.951', '1744876.572', '1744877.194']
#
# PROJECT ROOT DIR: /home/kesju/DI/2025_ZIVEO/PROJECT_TRAIN_UNET
# PROJECT DIR: /home/kesju/DI/2025_ZIVEO/PROJECT_TRAIN_UNET/0_COLLECT_ZIVE_DATA
#
# LIST_DIR: /home/kesju/DI/2025_ZIVEO/PROJECT_TRAIN_UNET/1_PREPARE_TRAIN_UNET_DATA/ecg_zive_npy_for_preparing
# REC_DIR: /home/kesju/DI/2025_ZIVEO/PROJECT_TRAIN_UNET/DATA_ORIG/ecg_zive_npy
# EXCEL_NAME: visi_zive_irasai_atrankai.xlsx
#
# Skaitomas Excel: %s /home/kesju/DI/2025_ZIVEO/PROJECT_TRAIN_UNET/1_PREPARE_TRAIN_UNET_DATA/ecg_zive_npy_for_preparing/visi_zive_irasai_atrankai.xlsx
# Įrašų sąraše: 1085
# CSV files: 105
# Excel rows: 1092
# Matches: 65
# 1000_1 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1000_2 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1001_1 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1001_2 {'FULLY_ANNOTATED_PROFESSIONALLY'}
# 1001_4 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1005_2 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1008_0 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1008_1 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1008_10 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1008_12 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1008_18 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1008_2 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1008_23 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1008_3 {'FOR_EXTERNAL_ANNOTATING', 'AI_DATASET', 'EXTERNALLY_ANNOTATED'}
# 1008_4 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1008_6 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1008_7 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1008_8 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1008_9 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1009_12 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1009_13 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1009_2 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1009_23 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1009_5 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1012_0 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1012_1 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1012_2 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1015_13 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_14 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_17 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_22 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_30 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_32 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_38 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_40 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_44 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_49 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_51 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_53 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_55 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1015_61 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1016_1 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_107 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_118 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_130 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_134 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_15 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_2 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_26 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1019_27 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_32 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_34 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_4 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_41 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1019_43 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_54 {'FOR_EXTERNAL_ANNOTATING', 'PSEUDO_ANNOTATED', 'EXTERNALLY_ANNOTATED'}
# 1019_63 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_74 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1019_77 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1025_0 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1025_1 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1025_2 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1025_3 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1025_4 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
# 1103_0 {'FOR_EXTERNAL_ANNOTATING', 'EXTERNALLY_ANNOTATED'}
#
# === MATCHES (same basename) ===
# filename              recordingId                   userId  tag    basename                                                         flags
#   1000_1 60f945e187cf66e97e37810e 6034c808d6c2740008035ede  NaN 1626941.468 EXTERNALLY_ANNOTATED,FOR_EXTERNAL_ANNOTATING,PSEUDO_ANNOTATED
#   1000_2 615516b62312e50c3f168e38 6034c808d6c2740008035ede 9999 1632923.661 EXTERNALLY_ANNOTATED,FOR_EXTERNAL_ANNOTATING,PSEUDO_ANNOTATED
#   1001_1 60efffba87cf660aac377fe7 60a917b354352a3df86dc1f2  NaN 1626330.744 EXTERNALLY_ANNOTATED,FOR_EXTERNAL_ANNOTATING,PSEUDO_ANNOTATED
#   1001_2 60f9188487cf669c7e3780b8 60a917b354352a3df86dc1f2  NaN 1626924.927                                FULLY_ANNOTATED_PROFESSIONALLY
#   1001_4 60f9188487cf6632713780c5 60a917b354352a3df86dc1f2  NaN 1626934.963 EXTERNALLY_ANNOTATED,FOR_EXTERNAL_ANNOTATING,PSEUDO_ANNOTATED
#   1005_2 613f56f73d08d4dc87cdcb40 613b1c6f3d08d4370acdc8f3  NaN 1630693.635 EXTERNALLY_ANNOTATED,FOR_EXTERNAL_ANNOTATING,PSEUDO_ANNOTATED
#   1008_0 613f58593d08d4cec1cdccf1 613b1d0c3d08d413ffcdc8f6 1111 1630771.589                  EXTERNALLY_ANNOTATED,FOR_EXTERNAL_ANNOTATING
#   1008_1 613f58593d08d44f8dcdccf5 613b1d0c3d08d413ffcdc8f6  NaN 1630764.137                  EXTERNALLY_ANNOTATED,FOR_EXTERNAL_ANNOTATING
#  1008_10 613f58593d08d401b0cdccf4 613b1d0c3d08d413ffcdc8f6  NaN 1630762.273                  EXTERNALLY_ANNOTATED,FOR_EXTERNAL_ANNOTATING
#  1008_12 613f58593d08d461c8cdcce8 613b1d0c3d08d413ffcdc8f6 1111 1630758.549                  EXTERNALLY_ANNOTATED,FOR_EXTERNAL_ANNOTATING
#  1008_18 613f58593d08d42c00cdccf6 613b1d0c3d08d413ffcdc8f6  NaN 1630761.032                  EXTERNALLY_ANNOTATED,FOR_EXTERNAL_ANNOTATING
#   1008_2 613f58593d08d40aeacdcceb 613b1d0c3d08d413ffcdc8f6  NaN 1630763.516                  EXTERNALLY_ANNOTATED,FOR_EXTERNAL_ANNOTATING
#  1008_23 613f58593d08d48446cdcd06 613b1d0c3d08d413ffcdc8f6  NaN 1630777.178                  EXTERNALLY_ANNOTATED,FOR_EXTERNAL_ANNOTATING
#   1008_3 613f58593d08d48596cdcce9 613b1d0c3d08d413ffcdc8f6  NaN 1630757.924       AI_DATASET,EXTERNALLY_ANNOTATED,FOR_EXTERNAL_ANNOTATING
#   1008_4 613f58593d08d43c7dcdccea 613b1d0c3d08d413ffcdc8f6  NaN 1630757.303                  EXTERNALLY_ANNOTATED,FOR_EXTERNAL_ANNOTATING
#   